# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('/content/drive/MyDrive/Salary_dataset.csv')
y_pred = slr.predict(df[['YearsExperience']])

plt.scatter(df.YearsExperience, df.Salary, color='blue')
plt.plot(df.YearsExperience, y_pred, color='red')
plt.xlabel('YearsExperience', color = 'red')
plt.ylabel('Salary', color = 'red')
plt.show()
slr.predict([[2.5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([48473.10977016])

# %%
slr.coef_
slr.intercept_
matching_score = 9449.96232146 * 2.5 + 24848.203966523208
matching_score
# Out:
# 48473.10977017321

# %%
slr.score(df[['YearsExperience']], df.Salary)
# Out:
# 0.9569566641435086
